# %% [markdown]
# ##Python List
# - List items are ordered, changeable, and allow duplicate values.
#
# - List items are indexed, the first item has index [0], the second item has index [1] etc.

# %%
#Python List
thislist = ["apple", "banana", "cherry"]
print(thislist) #access the list
print(len(thislist)) # element inside the list
list1 = ["abc", 34, True, 40, "male"] #list with mixed datatype
print(list1)
print(type(list1))
print(list1[1]) # access list item
print(list1[- 1]) #last item
#access range of list item
print(list1[2:4])
print(list1[:4])
print(list1[2:])

list1[1] = "blackcurrant" #change list item
list1[1:3] = ["blackcurrant", "watermelon"]
# Out:
# ['apple', 'banana', 'cherry']
# 3
# ['abc', 34, True, 40, 'male']
# <class 'list'>
# 34
# male
# [True, 40]
# ['abc', 34, True, 40]
# [True, 40, 'male']

# %%
#set, tuple
s=(2,3,4)
print(s[0])
# Out:
# 2

# %% [markdown]
# ## Python Dictonary
# Dictionaries are used to store data values in key:value pairs.
# - A dictionary is a collection which is ordered, changeable and do not allow duplicates*.

# %%
#create a dictonary and priny iy
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": [1964,2022,2023]
}
print(thisdict["year"][0])
# Out:
# 1964

# %%
#dictonary item
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["brand"]="Honda"
print(thisdict)
# Out:
# {'brand': 'Honda', 'model': 'Mustang', 'year': 1964}

# %%
# get the key
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

print(car.values())
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

#for x in thisdict.values():
#  print(x)

for x in thisdict:
  print(thisdict[x])
# Out:
# Ford
# Mustang
# 1964

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("brand")
thisdict["name"]="XYZ"
print(thisdict)
# Out:
# {'model': 'Mustang', 'year': 1964, 'name': 'XYZ'}

# %% [markdown]
# ## Python IF...ELSE

# %%
# If example
a = 33
b = 200
if b > a: #True/False
  print("b is greater than a")
# Out:
# b is greater than a

# %%
#ElseIF
a = 33
b = 33
if b > a: #True
  print("b is greater than a")
elif a==b:#True
  print("a and b are equal")
elif b<a:
  print("b is less than a")
else: #False, false
  print("a and b are equal")
# Out:
# a and b are equal

# %%
#Else
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 370
b = 330

#Short Hand IF
#if a > b: print("a is greater than b")

#Short Hand ElseIF
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# A

# %%
# Nested IF
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
#Pass statement
a = 33
b = 200

if b > a:
  pass

# %% [markdown]
# ##While loop
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
i = 1 #start
while i < 6: #condition check(need to be false one)
  print(i)
  i += 1     #increment/decrement
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##break statement
# With the break statement we can stop the loop even if the while condition is true:

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# ##continue statement
# With the continue statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# ## The Else Statement
# With the else statement we can run a block of code once when the condition no longer is true:

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [markdown]
# ##Python For Loop

# %%
#For loop theough list
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#For loop through string
string1="banana"
for x in string1:
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
#break and continue statement with for loop
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
    #continue
  print(x)
# Out:
# apple

# %% [markdown]
# #The range() funcation
# - To loop through a set of code a specified number of times, we can use the range() function,
# - The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.

# %%
#start 0 and end 5
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#start 2 and end 5
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
# start 2, end 29 and increment 3
for x in range(2, 30, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
#Nested Loop
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %% [markdown]
# ## Lenght of Last Word
# Given a string s consisting of words and spaces, return the length of the last word in the string.
#
# A word is a maximal
# substring
#  consisting of non-space characters only.
#
#
#
# Example 1:
# - Input: s = "Hello World"
# - Output: 5
# - Explanation: The last word is "World" with length 5.
#
# Example 2:
# - Input: s = "   fly me   to   the moon  "
# - Output: 4
# - Explanation: The last word is "moon" with length 4.
#
# Example 3:
# - Input: s = "luffy is still joyboy"
# - Output: 6
# - Explanation: The last word is "joyboy" with length 6.

# %%
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """
        length=0
        i=len(s)-1
        while i>=0 and s[i]==' ':
            i=i-1
        while i>=0 and s[i]!=' ':
            length=length+1
            i=i-1
        return length
