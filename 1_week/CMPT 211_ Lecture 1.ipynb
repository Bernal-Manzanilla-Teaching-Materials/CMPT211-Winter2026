# %% [markdown]
# # Python for Beginner

# %%
#check python verson
# !python --version
# Out:
# Python 3.10.12

# %%
# Print a message in python
print("Welcome to Python!")
# Out:
# Welcome to Python!

# %%
# Python single quotes vs double quotes
print("Welcome to Python!")
print('Welcome to Python!')
# Out:
# Welcome to Python!
# Welcome to Python!

# %%
#Take an input from user and print it
x=input("Insert a number:")
print(x)
# Out:
# Insert a number:987
# 987

# %% [markdown]
# **Python file extnsion:**
#    - Firstprogram.py: python file
#    - LabTest1.ipynb: this extension is used by Jupyter Notebook for interactive documents containing code, visulization and text.

# %% [markdown]
# **Python Indentation:** Indentation refers to the spaces at the beginning of a code line. Python uses indentation to indicate a block of code.
#  - put at least one indentation
#  - same number of space in same block of code

# %%
if 9>2:
 print('Nine is grater than two')
print('End of code block')
# Out:
# Nine is grater than two

# %% [markdown]
# **Python Variable:** A nambe of the memory location where you store/will store data
#
# Rule of variable name:
#  - A variable name must start with a letter or the underscore character
#  -A variable name cannot start with a number
#  -A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#  -Variable names are case-sensitive (age, Age and AGE are three different variables)
#  -A variable name cannot be any of the Python keywords.

# %%
x=10 # x is a variable
x='Hello, World!'

# %% [markdown]
# **Multi Words Variable Names:** Variable names with more than one word can be difficult to read. There are several techniques you can use to make them more readable:
#
# - Camel Case: Each word, except the first, starts with a capital letter
# - Pascal Case: Each word starts with a capital letter
# - Snake Case: Each word is separated by an underscore character

# %%
myVariableName = "John"
MyVariableName = "John"
my_variable_name = "John"

# %% [markdown]
# **Pyhton comments:** After the symbol #  Python will render the rest of the line as a comment
# - Single line vs multi line comment

# %%
#print('Hello World!')

# %%
#This is a comment
#written in
#more than just one line
print("Hello, World!")

"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!
# Hello, World!

# %% [markdown]
# **Python datatype:** Variables can store data of different types, and different types can do different things. Python has the following data types built-in by default, in these categories:
#
# - Text Type:	str
# - Numeric Types:	int, float, complex
# - Sequence Types:	list, tuple, range
# - Mapping Type:	dict
# - Set Types:	set, frozenset
# - Boolean Type:	bool
# - Binary Types:	bytes, bytearray, memoryview
# - None Type:	NoneType

# %%
# Example of data type
x = "Hello World"	#str
x = 20	#int
x = 20.5	#float
x = 1j	#complex
x = ["apple", "banana", "cherry"]	#list
x = ("apple", "banana", "cherry")	#tuple
x = range(6)	#range
x = {"name" : "John", "age" : 36}	#dict
x = {"apple", "banana", "cherry"}	#set
x = frozenset({"apple", "banana", "cherry"})	#frozenset
x = True	#bool
x = b"Hello"	#bytes
x = bytearray(5)	#bytearray
x = memoryview(bytes(5))	#memoryview
x = None

# %%
# check the datatype
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# #Python Problem Solving

# %% [markdown]
# ## Probelm 1: Two Sum
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# - You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# - You can return the answer in any order.
#
#
#
# Example 1:
# - Input: nums = [2,7,11,15], target = 9
# - Output: [0,1]
# - Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# Example 2:
# - Input: nums = [3,2,4], target = 6
# - Output: [1,2]
#
# Example 3:
# - Input: nums = [3,3], target = 6
# - Output: [0,1]

# %%
#Tentative solution
#This solution may have syntax or logical error
#Correct the code if necessary
def twoSum(nums, target):
  for i in range(0, len(nums)):
    for j in range(i+1, len(nums)):
      if (nums[i]+nums[j]==target):
       return i, j
      if j==len(nums) & i==j-1:
        print("No two sum solution")

# %% [markdown]
# ## Probelm 2: Palidrome Number
#
# Given an integer x, return true if x is a  palindrome, and false otherwise.
#
#
#
# Example 1:
# - Input: x = 121
# - Output: true
# - Explanation: 121 reads as 121 from left to right and from right to left.
#
# Example 2:
# - Input: x = -121
# - Output: false
# - Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
#
# Example 3:
# - Input: x = 10
# - Output: false
# - Explanation: Reads 01 from right to left. Therefore it is not a palindrome.

# %%
#Tentative solution
#This solution may have syntax or logical error
#Correct the code if necessary

def isPalindrome(num):
    num1=str(num)
    num2=num[::-1]
    if(num1==num2):
      print('Is Palindrome')
    else:
      print('Not palindrome')

# %% [markdown]
# ## Problem 3: [Recursive Algorithm](https://eng.libretexts.org/Bookshelves/Computer_Science/Databases_and_Data_Structures/Book%3A_Data_Structure_and_Algorithms_(Njoroge)/02%3A_Recursion/2.01%3A_Activity_1_-_Recursive_Algorithm#:~:text=Recursion%20is%20defined%20as%20a,to%20repeat%20the%20same%20steps.)
#
#
# Recursion is defined as a method of solving problems that involves breaking a problem down into smaller and smaller sub problems until you get to a small enough problem that it can be solved trivially. Simply this is done by the program calling itself to repeat the same steps.
#
# Recursive problems are solved by developing a recursive algorithm. A recursive algorithm is defined as an algorithm which can call itself with smaller (or simpler) input values, and which obtains the result for the current input by applying simple operations to the returned value for the smaller (or simpler) input. Thus if a problem can be solved by utilizing solutions to smaller versions of the same problem, and the smaller versions reduce to easily solvable cases, then it means that one can use a recursive algorithm to solve that problem.
#
# The recursive method comprises the following:
#
# - A base case where the recursion stops and begins to unwind, and
# - A recursive step where the method calls itself
#
# A point worth noting is that a recursive algorithm is said to wind up until the base case is reached and then unwinds. During the unwinding process, further statement programs “pending” may be called.
#
# Recursion is a mechanism whereby repetition can be achieved using a method that continues to call itself until some terminating value is reached, i.e. without using some specific repetition construct.
#
# **Solove Factorial Problem** using recursive algorithm

# %%
#Tentative solution
#This solution may have sytax or logical error
#Correct the code if necessary

def factorial(n):
    if(n>1):
      return (n*factorial(n-1))
    else:
      return 1

print(factorial(5))
# Out:
# 120
